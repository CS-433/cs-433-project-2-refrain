# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
import os,sys,csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import interp
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data_TF2(indel_list,data_path): # cell type specific  ## random samples for reactome is not enough, need borrow some from keggp
    import random
    import numpy as np
    xxdata_list = []
    yydata = []
    count_set = [0]
    count_setx = 0
    for i in indel_list:#len(h_tf_sc)):
        xdata = np.load(data_path+'/Nxdata_tf' + str(i) + '.npy')
        ydata = np.load(data_path+'/ydata_tf' + str(i) + '.npy')
        for k in range(len(ydata)):
            xxdata_list.append(xdata[k,:,:,:])
            yydata.append(ydata[k])
        count_setx = count_setx + len(ydata)
        count_set.append(count_setx)
        #print (i,len(ydata))
    yydata_array = np.array(yydata)
    yydata_x = yydata_array.astype('int')
    #print (np.array(xxdata_list).shape)
    return((np.array(xxdata_list),yydata_x,count_set))

# %%
csv_reader = csv.reader(open('generatedata/index_train.csv','r'))
trainindex=np.array(list(csv_reader)).shape[0]
csv_reader = csv.reader(open('generatedata/index_test.csv','r'))
testindex=np.array(list(csv_reader)).shape[0]

length_TF_train =int(trainindex-1)
length_TF_test =int(testindex-1)

data_path_train = "NEPDF_data_train"
data_path_test = "NEPDF_data_test"

num_classes = int(2)

train_TF = [i for i in range (length_TF_train)]
test_TF = [i for i in range (length_TF_test)]

(x_train, y_train,count_set_train) = load_data_TF2(train_TF,data_path_train)
(x_test, y_test,count_set) = load_data_TF2(test_TF,data_path_test)
print(x_train.shape, 'x_train samples')
print(x_test.shape, 'x_test samples')
# Out:
# (1250, 32, 32, 1) x_train samples
# (400, 32, 32, 1) x_test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_test.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))


model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])

# %%
batch_size=x_train.shape[0]
epochs=500
model_name='trained.h5'

# %%
save_dir="train_model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, verbose=0, mode='max')
checkpoint1 = ModelCheckpoint(filepath=save_dir + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, save_best_only=False, save_weights_only=False, mode='min', period=1)
checkpoint2 = ModelCheckpoint(filepath=save_dir + '/weights.hdf5', monitor='val_accuracy', verbose=1,
                              save_best_only=True, mode='max', period=1)
callbacks_list = [checkpoint2, early_stopping]


history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,validation_split=0.2,
          shuffle=True, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4770
# Epoch 00001: val_accuracy improved from -inf to 0.42000, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 255ms/step - loss: 0.6932 - accuracy: 0.4770 - val_loss: 0.6933 - val_accuracy: 0.4200
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.4930
# Epoch 00002: val_accuracy improved from 0.42000 to 0.48400, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6928 - accuracy: 0.4930 - val_loss: 0.6932 - val_accuracy: 0.4840
# Epoch 3/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5130
# Epoch 00003: val_accuracy improved from 0.48400 to 0.54000, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6927 - accuracy: 0.5130 - val_loss: 0.6932 - val_accuracy: 0.5400
# Epoch 4/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.4840
# Epoch 00004: val_accuracy improved from 0.54000 to 0.54400, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6925 - accuracy: 0.4840 - val_loss: 0.6932 - val_accuracy: 0.5440
# Epoch 5/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5240
# Epoch 00005: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6923 - accuracy: 0.5240 - val_loss: 0.6932 - val_accuracy: 0.5360
# Epoch 6/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5260
# Epoch 00006: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 96ms/step - loss: 0.
val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6909 - accuracy: 0.5880 - val_loss: 0.6920 - val_accuracy: 0.5120
# Epoch 30/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5800
# Epoch 00030: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6917 - accuracy: 0.5800 - val_loss: 0.6920 - val_accuracy: 0.5120
# Epoch 31/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5910
# Epoch 00031: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6912 - accuracy: 0.5910 - val_loss: 0.6919 - val_accuracy: 0.5080
# Epoch 32/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5860
# Epoch 00032: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6910 - accuracy: 0.5860 - val_loss: 0.6919 - val_accuracy: 0.5080
# Epoch 33/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5920
# Epoch 00033: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6911 - accuracy: 0.5920 - val_loss: 0.6918 - val_accuracy: 0.5080
# Epoch 34/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.6110
# Epoch 00034: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6911 - accuracy: 0.6110 - val_loss: 0.6917 - val_accuracy: 0.5080
# Epoch 35/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.6060
# Epoch 00035: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6909 - accuracy: 0.6060 - val_loss: 0.6916 - val_accuracy: 0.5080
# Epoch 36/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.6180
# Epoch 00036: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 103ms/step - loss: 0.6909 - accuracy: 0.6180 - val_loss: 0.6916 - val_accuracy: 0.5160
# Epoch 37/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.6190
# Epoch 00037: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6903 - accuracy: 0.6190 - val_loss: 0.6915 - val_accuracy: 0.5160
# Epoch 38/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.6110
# Epoch 00038: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6907 - accuracy: 0.6110 - val_loss: 0.6914 - val_accuracy: 0.5160
# Epoch 39/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.6300
# Epoch 00039: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6898 - accuracy: 0.6300 - val_loss: 0.6914 - val_accuracy: 0.5200
# Epoch 40/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.6040
# Epoch 00040: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6902 - accuracy: 0.6040 - val_loss: 0.6913 - val_accuracy: 0.5360
# Epoch 41/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.5920
# Epoch 00041: val_accuracy did not improve from 0.54400
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6901 - accuracy: 0.5920 - val_loss: 0.6912 - val_accuracy: 0.5360
# Epoch 42/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5990
# Epoch 00042: val_accuracy improved from 0.54400 to 0.55600, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6902 - accuracy: 0.5990 - val_loss: 0.6911 - val_accuracy: 0.5560
# Epoch 43/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.6200
# Epoch 00043: val_accuracy did not improve from 0.55600
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6899 - accuracy: 0.6200 - val_loss: 0.6910 - val_accuracy: 0.5440
# Epoch 44/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.6250
# Epoch 00044: val_accuracy improved from 0.55600 to 0.56000, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 132ms/step - loss: 0.6893 - accuracy: 0.6250 - val_loss: 0.6909 - val_accuracy: 0.5600
# Epoch 45/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.6170
# Epoch 00045: val_accuracy improved from 0.56000 to 0.56800, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 122ms/step - loss: 0.6895 - accuracy: 0.6170 - val_loss: 0.6908 - val_accuracy: 0.5680
# Epoch 46/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.6240
# Epoch 00046: val_accuracy did not improve from 0.56800
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6891 - accuracy: 0.6240 - val_loss: 0.6907 - val_accuracy: 0.5640
# Epoch 47/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.6230
# Epoch 00047: val_accuracy improved from 0.56800 to 0.58400, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 127ms/step - loss: 0.6888 - accuracy: 0.6230 - val_loss: 0.6906 - val_accuracy: 0.5840
# Epoch 48/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.6340
# Epoch 00048: val_accuracy improved from 0.58400 to 0.60800, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 128ms/step - loss: 0.
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6634 - accuracy: 0.6600 - val_loss: 0.6676 - val_accuracy: 0.6400

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.savefig(save_dir+'/end_result.pdf')

# %%
model_path=save_dir+"/"+"weights.hdf5"
model.load_weights(model_path)
y_predict=model.predict(x_test)

# %%
r=0
for i in range(y_predict.shape[0]):
    if y_predict[i]>0.5:
        y_predict[i]=1
    else:
        y_predict[i]=0
    if (y_predict[i]==y_test[i]):
        r=r+1
print (r/y_test.shape[0])
# Out:
# 0.6775

# %%
# performance visualization
def performance_visualization(labels, scores):
    p = Performance(labels, scores)
    print("confusion matrix")
    print(p.get_confusion_matrix())
    acc = p.accuracy()
    pre = p.precision()
    rec = p.recall()
    print('accuracy: %.2f' % acc)
    print('precision: %.2f' % pre)
    print('recall: %.2f' % rec)
    p.roc_plot()

# for classifier's performance evaluation
class Performance:

    def __init__(self, labels, scores, threshold=0.5):
        # true value of y
        self.labels = labels
        # predicted value of y
        self.scores = scores
        # classification threshold
        self.threshold = threshold
        self.db = self.get_db()
        self.TP, self.FP, self.FN, self.TN = self.get_confusion_matrix()

    def accuracy(self):
        return (self.TP + self.TN) / (self.TP + self.FN + self.FP + self.TN)

    def precision(self):
        return self.TP / (self.TP + self.FP)

    def recall(self):
        return self.TP / (self.TP + self.FN)

    def auc(self):
        auc = 0.
        prev_x = 0
        xy_arr = self.roc_coord()
        for x, y in xy_arr:
            if x != prev_x:
                auc += (x - prev_x) * y
                prev_x = x
        return auc

    # return coordinate of roc
    def roc_coord(self):
        xy_arr = []
        tp, fp = 0., 0.
        neg = self.TN + self.FP
        pos = self.TP + self.FN
        for i in range(len(self.db)):
            tp += self.db[i][0]
            fp += 1 - self.db[i][0]
            xy_arr.append([fp / neg, tp / pos])
        return xy_arr

    # plot roc
    def roc_plot(self):
        auc = self.auc()
        xy_arr = self.roc_coord()
        x = [_v[0] for _v in xy_arr]
        y = [_v[1] for _v in xy_arr]
        plt.title("ROC curve (AUC = %.4f)" % auc)
        plt.ylabel("True Positive Rate")
        plt.xlabel("False Positive Rate")
        plt.plot(x, y)
        plt.grid()
        plt.savefig("train_model/ROC.pdf")
        plt.show()

    def get_db(self):
        db = []
        for i in range(len(self.labels)):
            db.append([self.labels[i], self.scores[i]])
        db = sorted(db, key=lambda x: x[1], reverse=True)
        return db

    # calculate confusion matrix
    def get_confusion_matrix(self):
        tp, fp, fn, tn = 0., 0., 0., 0.
        for i in range(len(self.labels)):
            if self.labels[i] == 1 and self.scores[i] >= self.threshold:
                tp += 1
            elif self.labels[i] == 0 and self.scores[i] >= self.threshold:
                fp += 1
            elif self.labels[i] == 1 and self.scores[i] < self.threshold:
                fn += 1
            else:
                tn += 1
        return [tp, fp, fn, tn]

# %%
labels = y_test
scores = y_predict
performance_visualization(labels, scores)
# Out:
# confusion matrix
# [89.0, 18.0, 111.0, 182.0]
# accuracy: 0.68
# precision: 0.83
# recall: 0.45
