# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
import os,sys,csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import interp
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data_TF2(indel_list,data_path): # cell type specific  ## random samples for reactome is not enough, need borrow some from keggp
    import random
    import numpy as np
    xxdata_list = []
    yydata = []
    count_set = [0]
    count_setx = 0
    for i in indel_list:#len(h_tf_sc)):
        xdata = np.load(data_path+'/Nxdata_tf' + str(i) + '.npy')
        ydata = np.load(data_path+'/ydata_tf' + str(i) + '.npy')
        for k in range(len(ydata)):
            xxdata_list.append(xdata[k,:,:,:])
            yydata.append(ydata[k])
        count_setx = count_setx + len(ydata)
        count_set.append(count_setx)
        #print (i,len(ydata))
    yydata_array = np.array(yydata)
    yydata_x = yydata_array.astype('int')
    #print (np.array(xxdata_list).shape)
    return((np.array(xxdata_list),yydata_x,count_set))

# %%
csv_reader = csv.reader(open('generatedata/index_train.csv','r'))
trainindex=np.array(list(csv_reader)).shape[0]
csv_reader = csv.reader(open('generatedata/index_test.csv','r'))
testindex=np.array(list(csv_reader)).shape[0]

length_TF_train =int(trainindex-1)
length_TF_test =int(testindex-1)

data_path_train = "NEPDF_data_train"
data_path_test = "NEPDF_data_test"

num_classes = int(2)

train_TF = [i for i in range (length_TF_train)]
test_TF = [i for i in range (length_TF_test)]

(x_train, y_train,count_set_train) = load_data_TF2(train_TF,data_path_train)
(x_test, y_test,count_set) = load_data_TF2(test_TF,data_path_test)
print(x_train.shape, 'x_train samples')
print(x_test.shape, 'x_test samples')
# Out:
# (1152, 32, 32, 1) x_train samples
# (336, 32, 32, 1) x_test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_test.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))


model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])

# %%
batch_size=x_train.shape[0]
epochs=500
model_name='trained.h5'

# %%
save_dir="train_model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, verbose=0, mode='max')
checkpoint1 = ModelCheckpoint(filepath=save_dir + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, save_best_only=False, save_weights_only=False, mode='min', period=1)
checkpoint2 = ModelCheckpoint(filepath=save_dir + '/weights.hdf5', monitor='val_accuracy', verbose=1,
                              save_best_only=True, mode='max', period=1)
callbacks_list = [checkpoint2, early_stopping]


history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,validation_split=0.2,
          shuffle=True, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4810
# Epoch 00001: val_accuracy improved from -inf to 0.49784, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 404ms/step - loss: 0.6932 - accuracy: 0.4810 - val_loss: 0.6932 - val_accuracy: 0.4978
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4875
# Epoch 00002: val_accuracy improved from 0.49784 to 0.50216, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 141ms/step - loss: 0.6933 - accuracy: 0.4875 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 3/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5103
# Epoch 00003: val_accuracy improved from 0.50216 to 0.50649, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 123ms/step - loss: 0.6928 - accuracy: 0.5103 - val_loss: 0.6931 - val_accuracy: 0.5065
# Epoch 4/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5081
# Epoch 00004: val_accuracy improved from 0.50649 to 0.51515, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 149ms/step - loss: 0.6928 - accuracy: 0.5081 - val_loss: 0.6931 - val_accuracy: 0.5152
# Epoch 5/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4734
# Epoch 00005: val_accuracy improved from 0.51515 to 0.51948, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 128ms/step - loss: 0.6932 - accuracy: 0.4734 - val_loss: 0.6931 - val_accuracy: 0.5195
# Epoch 6/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4701
# Epoch 00006: val_accuracy did not improve from 0.51948
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6932 - accuracy: 0.4701 - val_loss: 0.6930 - val_accuracy: 0.5152
# Epoch 7/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5244
# Epoch 00007: val_accuracy did not improve from 0.51948
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6924 - accuracy: 0.5244 - val_loss: 0.6930 - val_accuracy: 0.5152
# Epoch 8/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4864
# Epoch 00008: val_accuracy did not improve from 0.51948
# 1/1 [==============================] - 0s 83ms/step - loss: 0.6930 - accuracy: 0.4864 - val_loss: 0.6930 - val_accuracy: 0.5152
# Epoch 9/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5147
# Epoch 00009: val_accuracy improved from 0.51948 to 0.55411, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 158ms/step - loss: 0.6927 - accuracy: 0.5147 - val_loss: 0.6929 - val_accuracy: 0.5541
# Epoch 10/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5190
# Epoch 00010: val_accuracy did not improve from 0.55411
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6926 - accuracy: 0.5190 - val_loss: 0.6929 - val_accuracy: 0.5498
# Epoch 11/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5081
# Epoch 00011: val_accuracy improved from 0.55411 to 0.56277, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 118ms/step - loss: 0.6929 - accuracy: 0.5081 - val_loss: 0.6929 - val_accuracy: 0.5628
# Epoch 12/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5103
# Epoch 00012: val_accuracy improved from 0.56277 to 0.57576, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6925 - accuracy: 0.5103 - val_loss: 0.6928 - val_accuracy: 0.5758
# Epoch 13/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5331
# Epoch 00013: val_accuracy did not improve from 0.57576
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6924 - accuracy: 0.5331 - val_loss: 0.6928 - val_accuracy: 0.5628
# Epoch 14/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4843
# Epoch 00014: val_accuracy improved from 0.57576 to 0.58874, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 164ms/step - loss: 0.6933 - accuracy: 0.4843 - val_loss: 0.6928 - val_accuracy: 0.5887
# Epoch 15/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.4973
# Epoch 00015: val_accuracy improved from 0.58874 to 0.61039, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 144ms/step - loss: 0.6929 - accuracy: 0.4973 - val_loss: 0.6927 - val_accuracy: 0.6104
# Epoch 16/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5342
# Epoch 00016: val_accuracy improved from 0.61039 to 0.61905, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.6925 - accuracy: 0.5342 - val_loss: 0.6927 - val_accuracy: 0.6190
# Epoch 17/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5266
# Epoch 00017: val_accuracy improved from 0.61905 to 0.63636, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 131ms/step - loss: 0.6926 - accuracy: 0.5266 - val_loss: 0.6927 - val_accuracy: 0.6364
# Epoch 18/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5179
# Epoch 00018: val_accuracy improved from 0.63636 to 0.64935, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6924 - accuracy: 0.5179 - val_loss: 0.6926 - val_accuracy: 0.6494
# Epoch 19/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5375
# Epoch 00019: val_accuracy improved from 0.64935 to 0.66234, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6923 - accuracy: 0.5375 - val_loss: 0.6926 - val_accuracy: 0.6623
# Epoch 20/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5516
# Epoch 00020: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6921 - accuracy: 0.5516 - val_loss: 0.6926 - val_accuracy: 0.6537
# Epoch 21/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5451
# Epoch 00021: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6920 - accuracy: 0.5451 - val_loss: 0.6926 - val_accuracy: 0.6580
# Epoch 22/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5700
# Epoch 00022: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6918 - accuracy: 0.5700 - val_loss: 0.6926 - val_accuracy: 0.6623
# Epoch 23/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5494
# Epoch 00023: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6920 - accuracy: 0.5494 - val_loss: 0.6925 - val_accuracy: 0.6580
# Epoch 24/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5396
# Epoch 00024: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6921 - accuracy: 0.5396 - val_loss: 0.6925 - val_accuracy: 0.6494
# Epoch 25/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5570
# Epoch 00025: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6919 - accuracy: 0.5570 - val_loss: 0.6925 - val_accuracy: 0.6104
# Epoch 26/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5494
# Epoch 00026: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6919 - accuracy: 0.5494 - val_loss: 0.6925 - val_accuracy: 0.5801
# Epoch 27/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5711
# Epoch 00027: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6916 - accuracy: 0.5711 - val_loss: 0.6925 - val_accuracy: 0.5714
# Epoch 28/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5418
# Epoch 00028: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 91ms/step - loss: 0.6919 - accuracy: 0.5418 - val_loss: 0.6925 - val_accuracy: 0.5671
# Epoch 29/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5700
# Epoch 00029: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6918 - accuracy: 0.5700 - val_loss: 0.6924 - val_accuracy: 0.5584
# Epoch 30/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5744
# Epoch 00030: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 91ms/step - loss: 0.6918 - accuracy: 0.5744 - val_loss: 0.6924 - val_accuracy: 0.5541
# Epoch 31/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5527
# Epoch 00031: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6920 - accuracy: 0.5527 - val_loss: 0.6924 - val_accuracy: 0.5498
# Epoch 32/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5603
# Epoch 00032: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6917 - accuracy: 0.5603 - val_loss: 0.6924 - val_accuracy: 0.5368
# Epoch 33/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.5689
# Epoch 00033: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6918 - accuracy: 0.5689 - val_loss: 0.6924 - val_accuracy: 0.5195
# Epoch 34/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5689
# Epoch 00034: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6916 - accuracy: 0.5689 - val_loss: 0.6924 - val_accuracy: 0.5108
# Epoch 35/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.6059
# Epoch 00035: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6913 - accuracy: 0.6059 - val_loss: 0.6923 - val_accuracy: 0.5108
# Epoch 36/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.6135
# Epoch 00036: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6911 - accuracy: 0.6135 - val_loss: 0.6923 - val_accuracy: 0.5108
# Epoch 37/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.5755
# Epoch 00037: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6914 - accuracy: 0.5755 - val_loss: 0.6923 - val_accuracy: 0.5108
# Epoch 38/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5689
# Epoch 00038: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6916 - accuracy: 0.5689 - val_loss: 0.6923 - val_accuracy: 0.5108
# Epoch 39/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5831
# Epoch 00039: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6912 - accuracy: 0.5831 - val_loss: 0.6923 - val_accuracy: 0.5108
# Epoch 40/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.6048
# Epoch 00040: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 88ms/step - loss: 0.6912 - accuracy: 0.6048 - val_loss: 0.6922 - val_accuracy: 0.5108
# Epoch 41/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5983
# Epoch 00041: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6910 - accuracy: 0.5983 - val_loss: 0.6922 - val_accuracy: 0.5108
# Epoch 42/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5798
# Epoch 00042: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6911 - accuracy: 0.5798 - val_loss: 0.6922 - val_accuracy: 0.5108
# Epoch 43/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5950
# Epoch 00043: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6910 - accuracy: 0.5950 - val_loss: 0.6922 - val_accuracy: 0.5108
# Epoch 44/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.6004
# Epoch 00044: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6913 - accuracy: 0.6004 - val_loss: 0.6922 - val_accuracy: 0.5108
# Epoch 45/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5950
# Epoch 00045: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6912 - accuracy: 0.5950 - val_loss: 0.6921 - val_accuracy: 0.5108
# Epoch 46/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.6145
# Epoch 00046: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6906 - accuracy: 0.6145 - val_loss: 0.6921 - val_accuracy: 0.5152
# Epoch 47/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.6145
# Epoch 00047: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6906 - accuracy: 0.6145 - val_loss: 0.6921 - val_accuracy: 0.5195
# Epoch 48/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.5983
# Epoch 00048: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6907 - accuracy: 0.5983 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 49/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.6243
# Epoch 00049: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6907 - accuracy: 0.6243 - val_loss: 0.6920 - val_accuracy: 0.5281
# Epoch 50/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.6243
# Epoch 00050: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6904 - accuracy: 0.6243 - val_loss: 0.6920 - val_accuracy: 0.5281
# Epoch 51/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.6232
# Epoch 00051: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 103ms/step - loss: 0.6906 - accuracy: 0.6232 - val_loss: 0.6920 - val_accuracy: 0.5325
# Epoch 52/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6908 - accuracy: 0.5907
# Epoch 00052: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6908 - accuracy: 0.5907 - val_loss: 0.6920 - val_accuracy: 0.5368
# Epoch 53/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.6048
# Epoch 00053: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6902 - accuracy: 0.6048 - val_loss: 0.6919 - val_accuracy: 0.5411
# Epoch 54/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6896 - accuracy: 0.6667
# Epoch 00054: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 91ms/step - loss: 0.6896 - accuracy: 0.6667 - val_loss: 0.6919 - val_accuracy: 0.5455
# Epoch 55/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.6200
# Epoch 00055: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6903 - accuracy: 0.6200 - val_loss: 0.6919 - val_accuracy: 0.5455
# Epoch 56/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.6102
# Epoch 00056: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6903 - accuracy: 0.6102 - val_loss: 0.6918 - val_accuracy: 0.5541
# Epoch 57/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.6243
# Epoch 00057: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6900 - accuracy: 0.6243 - val_loss: 0.6918 - val_accuracy: 0.5541
# Epoch 58/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.6048
# Epoch 00058: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 91ms/step - loss: 0.6902 - accuracy: 0.6048 - val_loss: 0.6917 - val_accuracy: 0.5584
# Epoch 59/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.6037
# Epoch 00059: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6900 - accuracy: 0.6037 - val_loss: 0.6917 - val_accuracy: 0.5584
# Epoch 60/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.6167
# Epoch 00060: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6899 - accuracy: 0.6167 - val_loss: 0.6917 - val_accuracy: 0.5584
# Epoch 61/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.6254
# Epoch 00061: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6897 - accuracy: 0.6254 - val_loss: 0.6916 - val_accuracy: 0.5671
# Epoch 62/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6899 - accuracy: 0.6069
# Epoch 00062: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 86ms/step - loss: 0.6899 - accuracy: 0.6069 - val_loss: 0.6916 - val_accuracy: 0.5671
# Epoch 63/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.6189
# Epoch 00063: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6897 - accuracy: 0.6189 - val_loss: 0.6916 - val_accuracy: 0.5671
# Epoch 64/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.6341
# Epoch 00064: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6891 - accuracy: 0.6341 - val_loss: 0.6915 - val_accuracy: 0.5671
# Epoch 65/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.6439
# Epoch 00065: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6894 - accuracy: 0.6439 - val_loss: 0.6915 - val_accuracy: 0.5671
# Epoch 66/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.6439
# Epoch 00066: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 90ms/step - loss: 0.6892 - accuracy: 0.6439 - val_loss: 0.6914 - val_accuracy: 0.5671
# Epoch 67/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.6428
# Epoch 00067: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 89ms/step - loss: 0.6887 - accuracy: 0.6428 - val_loss: 0.6914 - val_accuracy: 0.5671
# Epoch 68/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.6156
# Epoch 00068: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 117ms/step - loss: 0.6892 - accuracy: 0.6156 - val_loss: 0.6913 - val_accuracy: 0.5671
# Epoch 69/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.6189
# Epoch 00069: val_accuracy did not improve from 0.66234
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6890 - accuracy: 0.6189 - val_loss: 0.6913 - val_accuracy: 0.5671

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.savefig(save_dir+'/end_result.pdf')

# %%
model_path=save_dir+"/"+"weights.hdf5"
model.load_weights(model_path)
y_predict=model.predict(x_test)

# %%
r=0
for i in range(y_predict.shape[0]):
    if y_predict[i]>0.5:
        y_predict[i]=1
    else:
        y_predict[i]=0
    if (y_predict[i]==y_test[i]):
        r=r+1
print (r/y_test.shape[0])
# Out:
# 0.6964285714285714

# %%
# performance visualization
def performance_visualization(labels, scores):
    p = Performance(labels, scores)
    print("confusion matrix")
    print(p.get_confusion_matrix())
    acc = p.accuracy()
    pre = p.precision()
    rec = p.recall()
    print('accuracy: %.2f' % acc)
    print('precision: %.2f' % pre)
    print('recall: %.2f' % rec)
    p.roc_plot()

# for classifier's performance evaluation
class Performance:

    def __init__(self, labels, scores, threshold=0.5):
        # true value of y
        self.labels = labels
        # predicted value of y
        self.scores = scores
        # classification threshold
        self.threshold = threshold
        self.db = self.get_db()
        self.TP, self.FP, self.FN, self.TN = self.get_confusion_matrix()

    def accuracy(self):
        return (self.TP + self.TN) / (self.TP + self.FN + self.FP + self.TN)

    def precision(self):
        return self.TP / (self.TP + self.FP)

    def recall(self):
        return self.TP / (self.TP + self.FN)

    def auc(self):
        auc = 0.
        prev_x = 0
        xy_arr = self.roc_coord()
        for x, y in xy_arr:
            if x != prev_x:
                auc += (x - prev_x) * y
                prev_x = x
        return auc

    # return coordinate of roc
    def roc_coord(self):
        xy_arr = []
        tp, fp = 0., 0.
        neg = self.TN + self.FP
        pos = self.TP + self.FN
        for i in range(len(self.db)):
            tp += self.db[i][0]
            fp += 1 - self.db[i][0]
            xy_arr.append([fp / neg, tp / pos])
        return xy_arr

    # plot roc
    def roc_plot(self):
        auc = self.auc()
        xy_arr = self.roc_coord()
        x = [_v[0] for _v in xy_arr]
        y = [_v[1] for _v in xy_arr]
        plt.title("ROC curve (AUC = %.4f)" % auc)
        plt.ylabel("True Positive Rate")
        plt.xlabel("False Positive Rate")
        plt.plot(x, y)
        plt.grid()
        plt.savefig("train_model/ROC.pdf")
        plt.show()

    def get_db(self):
        db = []
        for i in range(len(self.labels)):
            db.append([self.labels[i], self.scores[i]])
        db = sorted(db, key=lambda x: x[1], reverse=True)
        return db

    # calculate confusion matrix
    def get_confusion_matrix(self):
        tp, fp, fn, tn = 0., 0., 0., 0.
        for i in range(len(self.labels)):
            if self.labels[i] == 1 and self.scores[i] >= self.threshold:
                tp += 1
            elif self.labels[i] == 0 and self.scores[i] >= self.threshold:
                fp += 1
            elif self.labels[i] == 1 and self.scores[i] < self.threshold:
                fn += 1
            else:
                tn += 1
        return [tp, fp, fn, tn]

# %%
labels = y_test
scores = y_predict
performance_visualization(labels, scores)
# Out:
# confusion matrix
# [121.0, 55.0, 47.0, 113.0]
# accuracy: 0.70
# precision: 0.69
# recall: 0.72
