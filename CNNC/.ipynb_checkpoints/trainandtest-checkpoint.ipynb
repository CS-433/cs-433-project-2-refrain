# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
import os,sys,csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import interp
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data_TF2(indel_list,data_path): # cell type specific  ## random samples for reactome is not enough, need borrow some from keggp
    import random
    import numpy as np
    xxdata_list = []
    yydata = []
    count_set = [0]
    count_setx = 0
    for i in indel_list:#len(h_tf_sc)):
        xdata = np.load(data_path+'/Nxdata_tf' + str(i) + '.npy')
        ydata = np.load(data_path+'/ydata_tf' + str(i) + '.npy')
        for k in range(len(ydata)):
            xxdata_list.append(xdata[k,:,:,:])
            yydata.append(ydata[k])
        count_setx = count_setx + len(ydata)
        count_set.append(count_setx)
        #print (i,len(ydata))
    yydata_array = np.array(yydata)
    yydata_x = yydata_array.astype('int')
    #print (np.array(xxdata_list).shape)
    return((np.array(xxdata_list),yydata_x,count_set))

# %%
csv_reader = csv.reader(open('generatedata/index_train.csv','r'))
trainindex=np.array(list(csv_reader)).shape[0]
csv_reader = csv.reader(open('generatedata/index_test.csv','r'))
testindex=np.array(list(csv_reader)).shape[0]

length_TF_train =int(trainindex-1)
length_TF_test =int(testindex-1)

data_path_train = "NEPDF_data_train"
data_path_test = "NEPDF_data_test"

num_classes = int(2)

train_TF = [i for i in range (length_TF_train)]
test_TF = [i for i in range (length_TF_test)]

(x_train, y_train,count_set_train) = load_data_TF2(train_TF,data_path_train)
(x_test, y_test,count_set) = load_data_TF2(test_TF,data_path_test)
print(x_train.shape, 'x_train samples')
print(x_test.shape, 'x_test samples')
# Out:
# (512, 32, 32, 1) x_train samples
# (160, 32, 32, 1) x_test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_test.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))


model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])

# %%
batch_size=x_train.shape[0]
epochs=500
model_name='trained.h5'

# %%
save_dir="train_model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, verbose=0, mode='max')
checkpoint1 = ModelCheckpoint(filepath=save_dir + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, save_best_only=False, save_weights_only=False, mode='min', period=1)
checkpoint2 = ModelCheckpoint(filepath=save_dir + '/weights.hdf5', monitor='val_accuracy', verbose=1,
                              save_best_only=True, mode='max', period=1)
callbacks_list = [checkpoint2, early_stopping]


history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,validation_split=0.2,
          shuffle=True, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.4205
# Epoch 00001: val_accuracy improved from -inf to 0.52427, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6941 - accuracy: 0.4205 - val_loss: 0.6932 - val_accuracy: 0.5243
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4499
# Epoch 00002: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6940 - accuracy: 0.4499 - val_loss: 0.6932 - val_accuracy: 0.5243
# Epoch 3/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4743
# Epoch 00003: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6934 - accuracy: 0.4743 - val_loss: 0.6932 - val_accuracy: 0.4757
# Epoch 4/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5379
# Epoch 00004: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6930 - accuracy: 0.5379 - val_loss: 0.6932 - val_accuracy: 0.4563
# Epoch 5/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4572
# Epoch 00005: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6935 - accuracy: 0.4572 - val_loss: 0.6932 - val_accuracy: 0.4272
# Epoch 6/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5257
# Epoch 00006: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 50ms/step - loss: 0.
val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6928 - accuracy: 0.5159 - val_loss: 0.6929 - val_accuracy: 0.4951
# Epoch 35/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4694
# Epoch 00035: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6936 - accuracy: 0.4694 - val_loss: 0.6929 - val_accuracy: 0.4951
# Epoch 36/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5061
# Epoch 00036: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6927 - accuracy: 0.5061 - val_loss: 0.6929 - val_accuracy: 0.4951
# Epoch 37/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5281
# Epoch 00037: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6931 - accuracy: 0.5281 - val_loss: 0.6929 - val_accuracy: 0.4951
# Epoch 38/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5037
# Epoch 00038: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6931 - accuracy: 0.5037 - val_loss: 0.6929 - val_accuracy: 0.4951
# Epoch 39/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5012
# Epoch 00039: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6931 - accuracy: 0.5012 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 40/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4817
# Epoch 00040: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6932 - accuracy: 0.4817 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 41/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4890
# Epoch 00041: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6933 - accuracy: 0.4890 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 42/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5183
# Epoch 00042: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6930 - accuracy: 0.5183 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 43/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5257
# Epoch 00043: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6928 - accuracy: 0.5257 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 44/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5306
# Epoch 00044: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6931 - accuracy: 0.5306 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 45/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5110
# Epoch 00045: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6931 - accuracy: 0.5110 - val_loss: 0.6928 - val_accuracy: 0.4951
# Epoch 46/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4988
# Epoch 00046: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6930 - accuracy: 0.4988 - val_loss: 0.6927 - val_accuracy: 0.4951
# Epoch 47/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5257
# Epoch 00047: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6929 - accuracy: 0.5257 - val_loss: 0.6927 - val_accuracy: 0.4951
# Epoch 48/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4988
# Epoch 00048: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6927 - val_accuracy: 0.4951
# Epoch 49/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.4768
# Epoch 00049: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6937 - accuracy: 0.4768 - val_loss: 0.6927 - val_accuracy: 0.4951
# Epoch 50/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5306
# Epoch 00050: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6927 - accuracy: 0.5306 - val_loss: 0.6927 - val_accuracy: 0.5049
# Epoch 51/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5232
# Epoch 00051: val_accuracy did not improve from 0.52427
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6928 - accuracy: 0.5232 - val_loss: 0.6927 - val_accuracy: 0.5243

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.savefig(save_dir+'/end_result.pdf')

# %%
model_path=save_dir+"/"+"weights.hdf5"
model.load_weights(model_path)
y_predict=model.predict(x_test)

# %%
r=0
for i in range(y_predict.shape[0]):
    if y_predict[i]>0.5:
        y_predict[i]=1
    else:
        y_predict[i]=0
    if (y_predict[i]==y_test[i]):
        r=r+1
print (r/y_test.shape[0])
# Out:
# 0.5125

# %%
plt.figure(figsize=(10, 6))
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_predict, pos_label=1)
plt.plot(fpr, tpr)
plt.grid()
plt.plot([0, 1], [0, 1])
plt.xlabel('FP')
plt.ylabel('TP')
plt.ylim([0, 1])
plt.xlim([0, 1])
auc = np.trapz(tpr, fpr)
print('AUC:', auc)
plt.savefig(save_dir + '/overall.pdf')
'''
DRAWING...
'''
# Out:
# AUC: 0.5125
# '\nDRAWING...\n'
