# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
import os,sys,csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import interp
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data_TF2(indel_list,data_path): # cell type specific  ## random samples for reactome is not enough, need borrow some from keggp
    import random
    import numpy as np
    xxdata_list = []
    yydata = []
    count_set = [0]
    count_setx = 0
    for i in indel_list:#len(h_tf_sc)):
        xdata = np.load(data_path+'/Nxdata_tf' + str(i) + '.npy')
        ydata = np.load(data_path+'/ydata_tf' + str(i) + '.npy')
        for k in range(len(ydata)):
            xxdata_list.append(xdata[k,:,:,:])
            yydata.append(ydata[k])
        count_setx = count_setx + len(ydata)
        count_set.append(count_setx)
        #print (i,len(ydata))
    yydata_array = np.array(yydata)
    yydata_x = yydata_array.astype('int')
    #print (np.array(xxdata_list).shape)
    return((np.array(xxdata_list),yydata_x,count_set))

# %%
csv_reader = csv.reader(open('generatedata/index_train.csv','r'))
trainindex=np.array(list(csv_reader)).shape[0]
csv_reader = csv.reader(open('generatedata/index_test.csv','r'))
testindex=np.array(list(csv_reader)).shape[0]

length_TF_train =int(trainindex-1)
length_TF_test =int(testindex-1)

data_path_train = "NEPDF_data_train"
data_path_test = "NEPDF_data_test"

num_classes = int(2)

train_TF = [i for i in range (length_TF_train)]
test_TF = [i for i in range (length_TF_test)]

(x_train, y_train,count_set_train) = load_data_TF2(train_TF,data_path_train)
(x_test, y_test,count_set) = load_data_TF2(test_TF,data_path_test)
print(x_train.shape, 'x_train samples')
print(x_test.shape, 'x_test samples')
# Out:
# (648, 32, 32, 1) x_train samples
# (216, 32, 32, 1) x_test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_test.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))


model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])

# %%
batch_size=x_train.shape[0]
epochs=500
model_name='trained.h5'

# %%
save_dir="train_model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, verbose=0, mode='max')
checkpoint1 = ModelCheckpoint(filepath=save_dir + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, save_best_only=False, save_weights_only=False, mode='min', period=1)
checkpoint2 = ModelCheckpoint(filepath=save_dir + '/weights.hdf5', monitor='val_accuracy', verbose=1,
                              save_best_only=True, mode='max', period=1)
callbacks_list = [checkpoint2, early_stopping]


history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,validation_split=0.2,
          shuffle=True, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4788
# Epoch 00001: val_accuracy improved from -inf to 0.49231, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 299ms/step - loss: 0.6932 - accuracy: 0.4788 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4672
# Epoch 00002: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6935 - accuracy: 0.4672 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 3/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4961
# Epoch 00003: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6934 - accuracy: 0.4961 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 4/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.4981
# Epoch 00004: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6929 - accuracy: 0.4981 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 5/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4846
# Epoch 00005: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6931 - accuracy: 0.4846 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 6/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4846
# Epoch 00006: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6930 - accuracy: 0.4846 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 7/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4884
# Epoch 00007: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6936 - accuracy: 0.4884 - val_loss: 0.6929 - val_accuracy: 0.4923
# Epoch 8/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 00008: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 9/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5154
# Epoch 00009: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6927 - accuracy: 0.5154 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 10/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4961
# Epoch 00010: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 11/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4710
# Epoch 00011: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6932 - accuracy: 0.4710 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 12/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5154
# Epoch 00012: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6928 - accuracy: 0.5154 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 13/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4768
# Epoch 00013: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6935 - accuracy: 0.4768 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 14/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5077
# Epoch 00014: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6929 - accuracy: 0.5077 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 15/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5077
# Epoch 00015: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6933 - accuracy: 0.5077 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 16/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4903
# Epoch 00016: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6930 - accuracy: 0.4903 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 17/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4807
# Epoch 00017: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6932 - accuracy: 0.4807 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 18/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4961
# Epoch 00018: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 63ms/step - loss: 0.6933 - accuracy: 0.4961 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 19/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4942
# Epoch 00019: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6934 - accuracy: 0.4942 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 20/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5058
# Epoch 00020: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6929 - accuracy: 0.5058 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 21/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5154
# Epoch 00021: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6927 - accuracy: 0.5154 - val_loss: 0.6930 - val_accuracy: 0.4923
# Epoch 22/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5097
# Epoch 00022: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6932 - accuracy: 0.5097 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 23/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5135
# Epoch 00023: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6927 - accuracy: 0.5135 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 24/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5270
# Epoch 00024: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6928 - accuracy: 0.5270 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 25/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4710
# Epoch 00025: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6932 - accuracy: 0.4710 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 26/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5212
# Epoch 00026: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6925 - accuracy: 0.5212 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 27/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5019
# Epoch 00027: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 28/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5174
# Epoch 00028: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6932 - accuracy: 0.5174 - val_loss: 0.6931 - val_accuracy: 0.4923
# Epoch 29/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5077
# Epoch 00029: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6930 - accuracy: 0.5077 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 30/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5309
# Epoch 00030: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6924 - accuracy: 0.5309 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 31/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5386
# Epoch 00031: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6927 - accuracy: 0.5386 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 32/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.4749
# Epoch 00032: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6929 - accuracy: 0.4749 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 33/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4788
# Epoch 00033: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6931 - accuracy: 0.4788 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 34/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5212
# Epoch 00034: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6931 - accuracy: 0.5212 - val_loss: 0.6933 - val_accuracy: 0.4923
# Epoch 35/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4846
# Epoch 00035: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6934 - accuracy: 0.4846 - val_loss: 0.6933 - val_accuracy: 0.4923
# Epoch 36/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5000
# Epoch 00036: val_accuracy did not improve from 0.49231
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.4923
# Epoch 37/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5174
# Epoch 00037: val_accuracy improved from 0.49231 to 0.50000, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6929 - accuracy: 0.5174 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 38/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5097
# Epoch 00038: val_accuracy did not improve from 0.50000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6931 - accuracy: 0.5097 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 39/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5174
# Epoch 00039: val_accuracy improved from 0.50000 to 0.51538, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 146ms/step - loss: 0.6929 - accuracy: 0.5174 - val_loss: 0.6933 - val_accuracy: 0.5154
# Epoch 40/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5212
# Epoch 00040: val_accuracy improved from 0.51538 to 0.52308, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 158ms/step - loss: 0.6928 - accuracy: 0.5212 - val_loss: 0.6933 - val_accuracy: 0.5231
# Epoch 41/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.4981
# Epoch 00041: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6926 - accuracy: 0.4981 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 42/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5483
# Epoch 00042: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6922 - accuracy: 0.5483 - val_loss: 0.6933 - val_accuracy: 0.5077
# Epoch 43/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5290
# Epoch 00043: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 65ms/step - loss: 0.6924 - accuracy: 0.5290 - val_loss: 0.6933 - val_accuracy: 0.5077
# Epoch 44/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5212
# Epoch 00044: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6925 - accuracy: 0.5212 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 45/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5174
# Epoch 00045: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6927 - accuracy: 0.5174 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 46/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4768
# Epoch 00046: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6934 - accuracy: 0.4768 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 47/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5039
# Epoch 00047: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6928 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 48/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.4923
# Epoch 00048: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6935 - accuracy: 0.4923 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 49/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5154
# Epoch 00049: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6927 - accuracy: 0.5154 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 50/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4961
# Epoch 00050: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6933 - accuracy: 0.4961 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 51/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5792
# Epoch 00051: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6923 - accuracy: 0.5792 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 52/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5290
# Epoch 00052: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6926 - accuracy: 0.5290 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 53/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5135
# Epoch 00053: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6927 - accuracy: 0.5135 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 54/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4923
# Epoch 00054: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6931 - accuracy: 0.4923 - val_loss: 0.6934 - val_accuracy: 0.5231
# Epoch 55/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5232
# Epoch 00055: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6931 - accuracy: 0.5232 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 56/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5000
# Epoch 00056: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 57/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5174
# Epoch 00057: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6933 - accuracy: 0.5174 - val_loss: 0.6934 - val_accuracy: 0.5231
# Epoch 58/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5058
# Epoch 00058: val_accuracy did not improve from 0.52308
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6932 - accuracy: 0.5058 - val_loss: 0.6934 - val_accuracy: 0.5154
# Epoch 59/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5367
# Epoch 00059: val_accuracy improved from 0.52308 to 0.53077, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 120ms/step - loss: 0.6924 - accuracy: 0.5367 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 60/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5309
# Epoch 00060: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6926 - accuracy: 0.5309 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 61/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5135
# Epoch 00061: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6924 - accuracy: 0.5135 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 62/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.4942
# Epoch 00062: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6929 - accuracy: 0.4942 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 63/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5039
# Epoch 00063: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6935 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 64/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5521
# Epoch 00064: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6922 - accuracy: 0.5521 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 65/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5019
# Epoch 00065: val_accuracy did not improve from 0.53077
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6928 - accuracy: 0.5019 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 66/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4575
# Epoch 00066: val_accuracy improved from 0.53077 to 0.54615, saving model to train_model/weights.hdf5
# 1/1 [==============================] - 0s 123ms/step - loss: 0.6939 - accuracy: 0.4575 - val_loss: 0.6934 - val_accuracy: 0.5462
# Epoch 67/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4768
# Epoch 00067: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6930 - accuracy: 0.4768 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 68/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5154
# Epoch 00068: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6925 - accuracy: 0.5154 - val_loss: 0.6934 - val_accuracy: 0.5462
# Epoch 69/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5174
# Epoch 00069: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6925 - accuracy: 0.5174 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 70/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5019
# Epoch 00070: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6930 - accuracy: 0.5019 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 71/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5405
# Epoch 00071: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6927 - accuracy: 0.5405 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 72/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5039
# Epoch 00072: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6930 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.5462
# Epoch 73/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5309
# Epoch 00073: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6924 - accuracy: 0.5309 - val_loss: 0.6934 - val_accuracy: 0.5462
# Epoch 74/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5193
# Epoch 00074: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6934 - accuracy: 0.5193 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 75/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5251
# Epoch 00075: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6929 - accuracy: 0.5251 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 76/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5000
# Epoch 00076: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 77/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5077
# Epoch 00077: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6932 - accuracy: 0.5077 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 78/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.4942
# Epoch 00078: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6930 - accuracy: 0.4942 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 79/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5154
# Epoch 00079: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6929 - accuracy: 0.5154 - val_loss: 0.6934 - val_accuracy: 0.5462
# Epoch 80/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000
# Epoch 00080: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 81/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5347
# Epoch 00081: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6927 - accuracy: 0.5347 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 82/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5154
# Epoch 00082: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6926 - accuracy: 0.5154 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 83/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5386
# Epoch 00083: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6920 - accuracy: 0.5386 - val_loss: 0.6934 - val_accuracy: 0.5385
# Epoch 84/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4826
# Epoch 00084: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6933 - accuracy: 0.4826 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 85/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5097
# Epoch 00085: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6927 - accuracy: 0.5097 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 86/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5328
# Epoch 00086: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6924 - accuracy: 0.5328 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 87/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4903
# Epoch 00087: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6934 - accuracy: 0.4903 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 88/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5058
# Epoch 00088: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6928 - accuracy: 0.5058 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 89/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5444
# Epoch 00089: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6919 - accuracy: 0.5444 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 90/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5058
# Epoch 00090: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6931 - accuracy: 0.5058 - val_loss: 0.6934 - val_accuracy: 0.5308
# Epoch 91/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4653
# Epoch 00091: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 61ms/step - loss: 0.6931 - accuracy: 0.4653 - val_loss: 0.6934 - val_accuracy: 0.5077
# Epoch 92/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4846
# Epoch 00092: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6932 - accuracy: 0.4846 - val_loss: 0.6934 - val_accuracy: 0.4923
# Epoch 93/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5347
# Epoch 00093: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6930 - accuracy: 0.5347 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 94/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.5347
# Epoch 00094: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6917 - accuracy: 0.5347 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 95/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5251
# Epoch 00095: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6923 - accuracy: 0.5251 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 96/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5154
# Epoch 00096: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6925 - accuracy: 0.5154 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 97/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5502
# Epoch 00097: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6923 - accuracy: 0.5502 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 98/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.5541
# Epoch 00098: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6924 - accuracy: 0.5541 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 99/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.4961
# Epoch 00099: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6926 - accuracy: 0.4961 - val_loss: 0.6934 - val_accuracy: 0.4769
# Epoch 100/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5116
# Epoch 00100: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6931 - accuracy: 0.5116 - val_loss: 0.6934 - val_accuracy: 0.4769
# Epoch 101/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5077
# Epoch 00101: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6930 - accuracy: 0.5077 - val_loss: 0.6934 - val_accuracy: 0.4692
# Epoch 102/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4981
# Epoch 00102: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6934 - val_accuracy: 0.4615
# Epoch 103/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5309
# Epoch 00103: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 58ms/step - loss: 0.6923 - accuracy: 0.5309 - val_loss: 0.6934 - val_accuracy: 0.4538
# Epoch 104/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5039
# Epoch 00104: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6933 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.4615
# Epoch 105/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5097
# Epoch 00105: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6929 - accuracy: 0.5097 - val_loss: 0.6934 - val_accuracy: 0.4538
# Epoch 106/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5193
# Epoch 00106: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6928 - accuracy: 0.5193 - val_loss: 0.6934 - val_accuracy: 0.4615
# Epoch 107/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5193
# Epoch 00107: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6930 - accuracy: 0.5193 - val_loss: 0.6934 - val_accuracy: 0.4538
# Epoch 108/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5039
# Epoch 00108: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6928 - accuracy: 0.5039 - val_loss: 0.6934 - val_accuracy: 0.4692
# Epoch 109/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.5521
# Epoch 00109: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6919 - accuracy: 0.5521 - val_loss: 0.6934 - val_accuracy: 0.4769
# Epoch 110/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5135
# Epoch 00110: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6929 - accuracy: 0.5135 - val_loss: 0.6934 - val_accuracy: 0.4846
# Epoch 111/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5502
# Epoch 00111: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6926 - accuracy: 0.5502 - val_loss: 0.6934 - val_accuracy: 0.4692
# Epoch 112/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5309
# Epoch 00112: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6925 - accuracy: 0.5309 - val_loss: 0.6935 - val_accuracy: 0.4769
# Epoch 113/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5000
# Epoch 00113: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4692
# Epoch 114/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000
# Epoch 00114: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4692
# Epoch 115/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5097
# Epoch 00115: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6930 - accuracy: 0.5097 - val_loss: 0.6935 - val_accuracy: 0.4769
# Epoch 116/500
# 1/1 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4981
# Epoch 00116: val_accuracy did not improve from 0.54615
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6931 - accuracy: 0.4981 - val_loss: 0.6935 - val_accuracy: 0.4769

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.savefig(save_dir+'/end_result.pdf')

# %%
model_path=save_dir+"/"+"weights.hdf5"
model.load_weights(model_path)
y_predict=model.predict(x_test)

# %%
r=0
for i in range(y_predict.shape[0]):
    if y_predict[i]>0.5:
        y_predict[i]=1
    else:
        y_predict[i]=0
    if (y_predict[i]==y_test[i]):
        r=r+1
print (r/y_test.shape[0])
# Out:
# 0.49537037037037035

# %%
# performance visualization
def performance_visualization(labels, scores):
    p = Performance(labels, scores)
    print("confusion matrix")
    print(p.get_confusion_matrix())
    acc = p.accuracy()
    pre = p.precision()
    rec = p.recall()
    print('accuracy: %.2f' % acc)
    print('precision: %.2f' % pre)
    print('recall: %.2f' % rec)
    p.roc_plot()

# for classifier's performance evaluation
class Performance:

    def __init__(self, labels, scores, threshold=0.5):
        # true value of y
        self.labels = labels
        # predicted value of y
        self.scores = scores
        # classification threshold
        self.threshold = threshold
        self.db = self.get_db()
        self.TP, self.FP, self.FN, self.TN = self.get_confusion_matrix()

    def accuracy(self):
        return (self.TP + self.TN) / (self.TP + self.FN + self.FP + self.TN)

    def precision(self):
        return self.TP / (self.TP + self.FP)

    def recall(self):
        return self.TP / (self.TP + self.FN)

    def auc(self):
        auc = 0.
        prev_x = 0
        xy_arr = self.roc_coord()
        for x, y in xy_arr:
            if x != prev_x:
                auc += (x - prev_x) * y
                prev_x = x
        return auc

    # return coordinate of roc
    def roc_coord(self):
        xy_arr = []
        tp, fp = 0., 0.
        neg = self.TN + self.FP
        pos = self.TP + self.FN
        for i in range(len(self.db)):
            tp += self.db[i][0]
            fp += 1 - self.db[i][0]
            xy_arr.append([fp / neg, tp / pos])
        return xy_arr

    # plot roc
    def roc_plot(self):
        auc = self.auc()
        xy_arr = self.roc_coord()
        x = [_v[0] for _v in xy_arr]
        y = [_v[1] for _v in xy_arr]
        plt.title("ROC curve (AUC = %.4f)" % auc)
        plt.ylabel("True Positive Rate")
        plt.xlabel("False Positive Rate")
        plt.plot(x, y)
        plt.grid()
        plt.savefig("train_model/ROC.pdf")
        plt.show()

    def get_db(self):
        db = []
        for i in range(len(self.labels)):
            db.append([self.labels[i], self.scores[i]])
        db = sorted(db, key=lambda x: x[1], reverse=True)
        return db

    # calculate confusion matrix
    def get_confusion_matrix(self):
        tp, fp, fn, tn = 0., 0., 0., 0.
        for i in range(len(self.labels)):
            if self.labels[i] == 1 and self.scores[i] >= self.threshold:
                tp += 1
            elif self.labels[i] == 0 and self.scores[i] >= self.threshold:
                fp += 1
            elif self.labels[i] == 1 and self.scores[i] < self.threshold:
                fn += 1
            else:
                tn += 1
        return [tp, fp, fn, tn]

# %%
labels = y_test
scores = y_predict
performance_visualization(labels, scores)
# Out:
# confusion matrix
# [81.0, 82.0, 27.0, 26.0]
# accuracy: 0.50
# precision: 0.50
# recall: 0.75
