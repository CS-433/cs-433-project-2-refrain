# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping,ModelCheckpoint
import os,sys,csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import interp
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data_TF2(indel_list,data_path): # cell type specific  ## random samples for reactome is not enough, need borrow some from keggp
    import random
    import numpy as np
    xxdata_list = []
    yydata = []
    count_set = [0]
    count_setx = 0
    for i in indel_list:#len(h_tf_sc)):
        xdata = np.load(data_path+'/Nxdata_tf' + str(i) + '.npy')
        ydata = np.load(data_path+'/ydata_tf' + str(i) + '.npy')
        for k in range(len(ydata)):
            xxdata_list.append(xdata[k,:,:,:])
            yydata.append(ydata[k])
        count_setx = count_setx + len(ydata)
        count_set.append(count_setx)
        #print (i,len(ydata))
    yydata_array = np.array(yydata)
    yydata_x = yydata_array.astype('int')
    #print (np.array(xxdata_list).shape)
    return((np.array(xxdata_list),yydata_x,count_set))

# %%
csv_reader = csv.reader(open('generatedata/index_train.csv','r'))
trainindex=np.array(list(csv_reader)).shape[0]
csv_reader = csv.reader(open('generatedata/index_test.csv','r'))
testindex=np.array(list(csv_reader)).shape[0]

length_TF_train =int(trainindex-1)
length_TF_test =int(testindex-1)

data_path_train = "NEPDF_data_train"
data_path_test = "NEPDF_data_test"

num_classes = int(2)

train_TF = [i for i in range (length_TF_train)]
test_TF = [i for i in range (length_TF_test)]

(x_train, y_train,count_set_train) = load_data_TF2(train_TF,data_path_train)
(x_test, y_test,count_set) = load_data_TF2(test_TF,data_path_test)
print(x_train.shape, 'x_train samples')
print(x_test.shape, 'x_test samples')
# Out:
# (1152, 32, 32, 1) x_train samples
# (336, 32, 32, 1) x_test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_test.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# model.add(Conv2D(128, (3, 3), padding='same'))
# model.add(Activation('relu'))
# model.add(Conv2D(128, (3, 3)))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))


model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,loss='binary_crossentropy',metrics=['accuracy'])

# %%
batch_size=32
epochs=200
model_name='trained.h5'

# %%
save_dir="train_model"
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, verbose=0, mode='max')
checkpoint1 = ModelCheckpoint(filepath=save_dir + '/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss',
                              verbose=1, save_best_only=False, save_weights_only=False, mode='min', period=1)
checkpoint2 = ModelCheckpoint(filepath=save_dir + '/weights.hdf5', monitor='val_accuracy', verbose=1,
                              save_best_only=True, mode='max', period=1)
callbacks_list = [checkpoint2, early_stopping]


history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,validation_split=0.2,
          shuffle=True, callbacks=callbacks_list)
model.save(save_dir+'/'+model_name)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 29/29 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4484
# Epoch 00001: val_accuracy improved from -inf to 0.50649, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 70ms/step - loss: 0.6938 - accuracy: 0.4484 - val_loss: 0.6931 - val_accuracy: 0.5065
# Epoch 2/200
# 29/29 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5440
# Epoch 00002: val_accuracy improved from 0.50649 to 0.52814, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 60ms/step - loss: 0.6926 - accuracy: 0.5440 - val_loss: 0.6925 - val_accuracy: 0.5281
# Epoch 3/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.6916 - accuracy: 0.5681
# Epoch 00003: val_accuracy improved from 0.52814 to 0.55411, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 58ms/step - loss: 0.6916 - accuracy: 0.5733 - val_loss: 0.6920 - val_accuracy: 0.5541
# Epoch 4/200
# 29/29 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.6167
# Epoch 00004: val_accuracy improved from 0.55411 to 0.56277, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 58ms/step - loss: 0.6909 - accuracy: 0.6167 - val_loss: 0.6915 - val_accuracy: 0.5628
# Epoch 5/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.
200
# 29/29 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.7633
# Epoch 00101: val_accuracy did not improve from 0.72727
# 29/29 [==============================] - 2s 69ms/step - loss: 0.4473 - accuracy: 0.7633 - val_loss: 0.5797 - val_accuracy: 0.6840
# Epoch 102/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.7796
# Epoch 00102: val_accuracy improved from 0.72727 to 0.73160, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 70ms/step - loss: 0.4390 - accuracy: 0.7796 - val_loss: 0.5793 - val_accuracy: 0.7316
# Epoch 103/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.7774
# Epoch 00103: val_accuracy did not improve from 0.73160
# 29/29 [==============================] - 2s 65ms/step - loss: 0.4405 - accuracy: 0.7774 - val_loss: 0.5730 - val_accuracy: 0.7186
# Epoch 104/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4437 - accuracy: 0.7687
# Epoch 00104: val_accuracy did not improve from 0.73160
# 29/29 [==============================] - 2s 66ms/step - loss: 0.4437 - accuracy: 0.7687 - val_loss: 0.5754 - val_accuracy: 0.7273
# Epoch 105/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4408 - accuracy: 0.7768
# Epoch 00105: val_accuracy did not improve from 0.73160
# 29/29 [==============================] - 2s 64ms/step - loss: 0.4428 - accuracy: 0.7720 - val_loss: 0.5745 - val_accuracy: 0.7143
# Epoch 106/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4356 - accuracy: 0.7913
# Epoch 00106: val_accuracy did not improve from 0.73160
# 29/29 [==============================] - 2s 63ms/step - loss: 0.4360 - accuracy: 0.7894 - val_loss: 0.5785 - val_accuracy: 0.7013
# Epoch 107/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4273 - accuracy: 0.7801
# Epoch 00107: val_accuracy did not improve from 0.73160
# 29/29 [==============================] - 2s 71ms/step - loss: 0.4310 - accuracy: 0.7774 - val_loss: 0.5718 - val_accuracy: 0.7143
# Epoch 108/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.7796
# Epoch 00108: val_accuracy improved from 0.73160 to 0.73593, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 71ms/step - loss: 0.4272 - accuracy: 0.7796 - val_loss: 0.5681 - val_accuracy: 0.7359
# Epoch 109/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4327 - accuracy: 0.7857
# Epoch 00109: val_accuracy did not improve from 0.73593
# 29/29 [==============================] - 2s 65ms/step - loss: 0.4355 - accuracy: 0.7861 - val_loss: 0.5700 - val_accuracy: 0.6797
# Epoch 110/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4394 - accuracy: 0.7667
# Epoch 00110: val_accuracy did not improve from 0.73593
# 29/29 [==============================] - 2s 65ms/step - loss: 0.4355 - accuracy: 0.7698 - val_loss: 0.5827 - val_accuracy: 0.7316
# Epoch 111/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4296 - accuracy: 0.7757
# Epoch 00111: val_accuracy did not improve from 0.73593
# 29/29 [==============================] - 2s 65ms/step - loss: 0.4294 - accuracy: 0.7774 - val_loss: 0.5637 - val_accuracy: 0.7229
# Epoch 112/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4222 - accuracy: 0.7883
# Epoch 00112: val_accuracy improved from 0.73593 to 0.74026, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 66ms/step - loss: 0.4222 - accuracy: 0.7883 - val_loss: 0.5605 - val_accuracy: 0.7403
# Epoch 113/200
# 29/29 [==============================] - ETA: 0s - loss: 0.4336 - accuracy: 0.7720
# Epoch 00113: val_accuracy improved from 0.74026 to 0.74459, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 66ms/step - loss: 0.4336 - accuracy: 0.7720 - val_loss: 0.5562 - val_accuracy: 0.7446
# Epoch 114/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.4419 - accuracy: 0.7790
# Epoch 00114: val_accuracy did not improve from 0.74459
# 29/29 [==============================] - 2s 61ms/step - loss: 0.4379 - accuracy: 0.7839 - val_loss: 0.5502 - val_accuracy: 0.7446
# Epoch 115/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.77489
# 29/29 [==============================] - 2s 60ms/step - loss: 0.3563 - accuracy: 0.8187 - val_loss: 0.4828 - val_accuracy: 0.7706
# Epoch 188/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8143
# Epoch 00188: val_accuracy did not improve from 0.77489
# 29/29 [==============================] - 2s 63ms/step - loss: 0.3575 - accuracy: 0.8143 - val_loss: 0.4811 - val_accuracy: 0.7662
# Epoch 189/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3550 - accuracy: 0.8125
# Epoch 00189: val_accuracy did not improve from 0.77489
# 29/29 [==============================] - 2s 65ms/step - loss: 0.3581 - accuracy: 0.8100 - val_loss: 0.4737 - val_accuracy: 0.7619
# Epoch 190/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3659 - accuracy: 0.8036
# Epoch 00190: val_accuracy improved from 0.77489 to 0.77922, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 64ms/step - loss: 0.3630 - accuracy: 0.8056 - val_loss: 0.4860 - val_accuracy: 0.7792
# Epoch 191/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3737 - accuracy: 0.8092
# Epoch 00191: val_accuracy did not improve from 0.77922
# 29/29 [==============================] - 2s 63ms/step - loss: 0.3707 - accuracy: 0.8122 - val_loss: 0.4865 - val_accuracy: 0.7749
# Epoch 192/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8046
# Epoch 00192: val_accuracy did not improve from 0.77922
# 29/29 [==============================] - 2s 69ms/step - loss: 0.3586 - accuracy: 0.8046 - val_loss: 0.4902 - val_accuracy: 0.7532
# Epoch 193/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8089
# Epoch 00193: val_accuracy improved from 0.77922 to 0.78355, saving model to train_model/weights.hdf5
# 29/29 [==============================] - 2s 66ms/step - loss: 0.3673 - accuracy: 0.8089 - val_loss: 0.4833 - val_accuracy: 0.7835
# Epoch 194/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3611 - accuracy: 0.8132
# Epoch 00194: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 65ms/step - loss: 0.3611 - accuracy: 0.8132 - val_loss: 0.4878 - val_accuracy: 0.7532
# Epoch 195/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3558 - accuracy: 0.8136
# Epoch 00195: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 64ms/step - loss: 0.3569 - accuracy: 0.8132 - val_loss: 0.5034 - val_accuracy: 0.7792
# Epoch 196/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8219
# Epoch 00196: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 64ms/step - loss: 0.3574 - accuracy: 0.8219 - val_loss: 0.4802 - val_accuracy: 0.7792
# Epoch 197/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8219
# Epoch 00197: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 68ms/step - loss: 0.3603 - accuracy: 0.8219 - val_loss: 0.4839 - val_accuracy: 0.7749
# Epoch 198/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3586 - accuracy: 0.8225
# Epoch 00198: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 62ms/step - loss: 0.3599 - accuracy: 0.8198 - val_loss: 0.4862 - val_accuracy: 0.7749
# Epoch 199/200
# 29/29 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8176
# Epoch 00199: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 62ms/step - loss: 0.3491 - accuracy: 0.8176 - val_loss: 0.4901 - val_accuracy: 0.7706
# Epoch 200/200
# 28/29 [===========================>..] - ETA: 0s - loss: 0.3550 - accuracy: 0.8248
# Epoch 00200: val_accuracy did not improve from 0.78355
# 29/29 [==============================] - 2s 61ms/step - loss: 0.3544 - accuracy: 0.8263 - val_loss: 0.4855 - val_accuracy: 0.7749

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid()
plt.legend(['train', 'val'], loc='upper left')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.savefig(save_dir+'/end_result.pdf')

# %%
model_path=save_dir+"/"+"weights.hdf5"
model.load_weights(model_path)
y_predict=model.predict(x_test)

# %%
r=0
for i in range(y_predict.shape[0]):
    if y_predict[i]>0.5:
        y_predict[i]=1
    else:
        y_predict[i]=0
    if (y_predict[i]==y_test[i]):
        r=r+1
print (r/y_test.shape[0])
# Out:
# 0.7916666666666666

# %%
# performance visualization
def performance_visualization(labels, scores):
    p = Performance(labels, scores)
    print("confusion matrix")
    print(p.get_confusion_matrix())
    acc = p.accuracy()
    pre = p.precision()
    rec = p.recall()
    print('accuracy: %.2f' % acc)
    print('precision: %.2f' % pre)
    print('recall: %.2f' % rec)
    p.roc_plot()

# for classifier's performance evaluation
class Performance:

    def __init__(self, labels, scores, threshold=0.5):
        # true value of y
        self.labels = labels
        # predicted value of y
        self.scores = scores
        # classification threshold
        self.threshold = threshold
        self.db = self.get_db()
        self.TP, self.FP, self.FN, self.TN = self.get_confusion_matrix()

    def accuracy(self):
        return (self.TP + self.TN) / (self.TP + self.FN + self.FP + self.TN)

    def precision(self):
        return self.TP / (self.TP + self.FP)

    def recall(self):
        return self.TP / (self.TP + self.FN)

    def auc(self):
        auc = 0.
        prev_x = 0
        xy_arr = self.roc_coord()
        for x, y in xy_arr:
            if x != prev_x:
                auc += (x - prev_x) * y
                prev_x = x
        return auc

    # return coordinate of roc
    def roc_coord(self):
        xy_arr = []
        tp, fp = 0., 0.
        neg = self.TN + self.FP
        pos = self.TP + self.FN
        for i in range(len(self.db)):
            tp += self.db[i][0]
            fp += 1 - self.db[i][0]
            xy_arr.append([fp / neg, tp / pos])
        return xy_arr

    # plot roc
    def roc_plot(self):
        auc = self.auc()
        xy_arr = self.roc_coord()
        x = [_v[0] for _v in xy_arr]
        y = [_v[1] for _v in xy_arr]
        plt.title("ROC curve (AUC = %.4f)" % auc)
        plt.ylabel("True Positive Rate")
        plt.xlabel("False Positive Rate")
        plt.plot(x, y)
        plt.grid()
        plt.savefig("train_model/ROC.pdf")
        plt.show()

    def get_db(self):
        db = []
        for i in range(len(self.labels)):
            db.append([self.labels[i], self.scores[i]])
        db = sorted(db, key=lambda x: x[1], reverse=True)
        return db

    # calculate confusion matrix
    def get_confusion_matrix(self):
        tp, fp, fn, tn = 0., 0., 0., 0.
        for i in range(len(self.labels)):
            if self.labels[i] == 1 and self.scores[i] >= self.threshold:
                tp += 1
            elif self.labels[i] == 0 and self.scores[i] >= self.threshold:
                fp += 1
            elif self.labels[i] == 1 and self.scores[i] < self.threshold:
                fn += 1
            else:
                tn += 1
        return [tp, fp, fn, tn]

# %%
labels = y_test
scores = y_predict
performance_visualization(labels, scores)
# Out:
# confusion matrix
# [142.0, 44.0, 26.0, 124.0]
# accuracy: 0.79
# precision: 0.76
# recall: 0.85

# %%
# model=load_model("modified.h5")

# for i in range(len(test)):
#     x=np.array(counts[test[i]])
#     k=0
#     for j in range(len(train)):
#         y=np.array(counts[train[j]])  
#         mat=get_NEPDF(x,y)
#         y_predict=np.rint(model.predict(mat))
#         l=l+y_predict
#     k=1.0*l/len(test)
#     if abs(k)>0.5 and label[i]=='1':
#         s=s+1
#     elif abs(k)<0.5 and label[i]=='0':
#         s=s+1

# print ("CNNC: ")
# print (s/len(label))
